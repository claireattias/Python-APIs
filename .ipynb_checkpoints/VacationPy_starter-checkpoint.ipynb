# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    city_id             city      Lat       Lng  Max Temp  Humidity  \
# 0        0             hilo  19.7297 -155.0900     77.11        85
# 1        1      east london -33.0153   27.9116     74.73        84
# 2        2   cabo san lucas  22.8909 -109.9124     81.61        50
# 3        3      yellowknife  62.4560 -114.3525      1.69        95
# 4        4  arraial do cabo -22.9661  -42.0278     78.66        83
#
#    Cloudiness  Wind Speed Country        Date
# 0          75        5.75      US  1675725314
# 1          23       15.28      ZA  1675725318
# 2           0       13.80      MX  1675725200
# 3         100        7.49      CA  1675725053
# 4          75        5.75      BR  1675725322

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    titles = "EsriNatGeo",
    size = "Humidity",
    color = "city",
    geo = True,
    scale = 0.5,
    frame_width = 800,
    frame_height = 600)

# Display the map
map_plot_1
# Out:
# WARNING:param.main: titles option not found for points plot with bokeh; similar options include: ['title', 'tiles']
# :Points   [Lng,Lat]   (city,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_df = city_data_df[(city_data_df['Max Temp']>69)&(city_data_df['Max Temp']<80)&(city_data_df['Humidity']<50)].copy()

# Drop any rows with null values
city_df.dropna(inplace=True)

# Display sample data
city_df
# Out:
#      city_id                city      Lat       Lng  Max Temp  Humidity  \
# 70        70            araouane  18.9048   -3.5265     71.49        13
# 103      103  comodoro rivadavia -45.8667  -67.5000     71.46        37
# 106      106       alice springs -23.7000  133.8833     76.55        31
# 183      183               arlit  18.7369    7.3853     71.80        14
# 188      188             tokonou   9.6500   -9.7833     78.06        19
# 222      222               goure  13.9835   10.2704     69.53        13
# 230      230            la palma  33.8464 -118.0467     72.18        38
# 299      299             yavaros  26.7000 -109.5167     72.73        40
# 312      312                kabo   7.6994   18.6290     76.03        15
# 350      350              riyadh  24.6877   46.7219     71.74        38
# 381      381              viedma -40.8135  -62.9967     70.47        39
# 396      396                doka  13.5167   35.7667     78.28        21
# 400      400                bara  10.3744   10.7288     77.54        17
# 433      433            kolokani  13.5728   -8.0339     79.38        14
# 442      442         bongandanga   1.5000   21.0500     76.68        42
# 445      445           sahuaripa  29.0500 -109.2333     77.50        11
# 508      508              ocampo  21.6500 -101.5000     70.93        11
# 517      517              garoua   9.3000   13.4000     78.94        17
#
#      Cloudiness  Wind Speed Country        Date
# 70          100        9.28      ML  1675725366
# 103           0        6.91      AR  1675725391
# 106          75        6.91      AU  1675725154
# 183         100        7.00      NE  1675725347
# 188          99        2.93      GN  1675725450
# 222         100        9.57      NE  1675725474
# 230          20        8.05      US  1675725479
# 299          84       15.43      MX  1675725524
# 312           6        4.99      CF  1675725533
# 350          12       10.36      SA  1675725504
# 381          31       15.39      AR  1675725578
# 396          87       13.96      SD  1675725495
# 400         100       11.83      NG  1675725590
# 433          95        8.61      ML  1675725612
# 442          74        1.41      CD  1675725618
# 445          97       15.88      MX  1675725621
# 508           1       10.36      MX  1675725662
# 517          82        3.69      CM  1675725669

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_df[['city','Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                    city Country      Lat       Lng  Humidity Hotel Name
# 70             araouane      ML  18.9048   -3.5265        13
# 103  comodoro rivadavia      AR -45.8667  -67.5000        37
# 106       alice springs      AU -23.7000  133.8833        31
# 183               arlit      NE  18.7369    7.3853        14
# 188             tokonou      GN   9.6500   -9.7833        19
# 222               goure      NE  13.9835   10.2704        13
# 230            la palma      US  33.8464 -118.0467        38
# 299             yavaros      MX  26.7000 -109.5167        40
# 312                kabo      CF   7.6994   18.6290        15
# 350              riyadh      SA  24.6877   46.7219        38
# 381              viedma      AR -40.8135  -62.9967        39
# 396                doka      SD  13.5167   35.7667        21
# 400                bara      NG  10.3744   10.7288        17
# 433            kolokani      ML  13.5728   -8.0339        14
# 442         bongandanga      CD   1.5000   21.0500        42
# 445           sahuaripa      MX  29.0500 -109.2333        11
# 508              ocampo      MX  21.6500 -101.5000        11
# 517              garoua      CM   9.3000   13.4000        17

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# get latitude, longitude from the DataFrame
lat = hotel_df['Lat']
lng = hotel_df['Lng']

# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel", 
    "apiKey":geoapify_key,
    "limit":20,
    "filter":f"circle:{lng},{lat},{radius}",
    "bias":f"proximity:{lng},{lat}" 
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty / convert to JSON
    url = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'city']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# araouane - nearest hotel: No hotel found
# comodoro rivadavia - nearest hotel: No hotel found
# alice springs - nearest hotel: No hotel found
# arlit - nearest hotel: No hotel found
# tokonou - nearest hotel: No hotel found
# goure - nearest hotel: No hotel found
# la palma - nearest hotel: No hotel found
# yavaros - nearest hotel: No hotel found
# kabo - nearest hotel: No hotel found
# riyadh - nearest hotel: No hotel found
# viedma - nearest hotel: No hotel found
# doka - nearest hotel: No hotel found
# bara - nearest hotel: No hotel found
# kolokani - nearest hotel: No hotel found
# bongandanga - nearest hotel: No hotel found
# sahuaripa - nearest hotel: No hotel found
# ocampo - nearest hotel: No hotel found
# garoua - nearest hotel: No hotel found
#                    city Country      Lat       Lng  Humidity      Hotel Name
# 70             araouane      ML  18.9048   -3.5265        13  No hotel found
# 103  comodoro rivadavia      AR -45.8667  -67.5000        37  No hotel found
# 106       alice springs      AU -23.7000  133.8833        31  No hotel found
# 183               arlit      NE  18.7369    7.3853        14  No hotel found
# 188             tokonou      GN   9.6500   -9.7833        19  No hotel found
# 222               goure      NE  13.9835   10.2704        13  No hotel found
# 230            la palma      US  33.8464 -118.0467        38  No hotel found
# 299             yavaros      MX  26.7000 -109.5167        40  No hotel found
# 312                kabo      CF   7.6994   18.6290        15  No hotel found
# 350              riyadh      SA  24.6877   46.7219        38  No hotel found
# 381              viedma      AR -40.8135  -62.9967        39  No hotel found
# 396                doka      SD  13.5167   35.7667        21  No hotel found
# 400                bara      NG  10.3744   10.7288        17  No hotel found
# 433            kolokani      ML  13.5728   -8.0339        14  No hotel found
# 442         bongandanga      CD   1.5000   21.0500        42  No hotel found
# 445           sahuaripa      MX  29.0500 -109.2333        11  No hotel found
# 508              ocampo      MX  21.6500 -101.5000        11  No hotel found
# 517              garoua      CM   9.3000   13.4000        17  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    titles = "city",
    size = "Humidity",
    color = "city",
    geo = True,
    scale = 0.5,
    frame_width = 800,
    frame_height = 600,
    hover_cols = ["Hotel Name", "Country"])

# Display the map
map_plot_2
# Out:
# WARNING:param.main: titles option not found for points plot with bokeh; similar options include: ['title', 'tiles']
# :Points   [Lng,Lat]   (city,Humidity,Hotel Name,Country)
