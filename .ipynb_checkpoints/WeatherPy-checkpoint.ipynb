# %%
# import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# import the OpenWeatherMap API key
from api_keys import weather_api_key

# import citipy to determine the citites based on latitude and longitude
from citipy import citipy

# %%
# generate random geographic coordinates and a list of cities

# %%
# generate cities list using citipy library 

# create empty list for holding the latitude and longitude combinations
lat_lng = []

# create empty list for holding the citites names
cities = []

# set range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# create a set of rangom lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # if the city is unique, add it to our citites list
    if city not in cities:
        cities.append(city)

# print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %%
# create plots to showcase the relationship between weather variables and latitude 
# use OpenWeatherMap API to retrieve weather data from the cities list

# %%
# create empty list to fetch weather data for each city
city_data = []

# print to logger
print("Beginning Data Retrieval      ")
print("------------------------------")

# create counters
record_count = 1
set_count = 1

# loop through all the cities in list to fetch weather data
for i, city in enumerate(cities):
    
    # set the API base URL (imperial = fahrenheit)
    url = f'https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q={city}'
    
    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    
    # log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    # add 1 to the record count
    record_count += 1
    
    # run an API request for each of the cities
    try:
        # parse the JSON and retrieve data
        city_weather = requests.get(url).json()
        
        # look at the data
        # city_weather
        
        # parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # append the city information into city_data list
        city_data.append({"city": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
        # if an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# indicate that data loading is complete
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | sao jose da coroa grande
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | lorengau
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | leningradskiy
# Processing Record 12 of Set 1 | sambava
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | pisco
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | nelson bay
# Processing Record 19 of Set 1 | sesimbra
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 1 | vardo
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | namtsy
# Processing Record 25 of Set 1 | marsa matruh
# Processing Record 26 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 1 | saint-augustin
# Processing Record 28 of Set 1 | chapais
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | lagoa
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | sonoita
# Processing Record 33 of Set 1 | haines junction
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | cassilandia
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | hasaki
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | el prat de llobregat
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | port lincoln
# Processing Record 47 of Set 1 | hit
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | channel-port aux basques
# Processing Record 50 of Set 1 | zhezkazgan
# Processing Record 0 of Set 2 | atuona
# Processing Record 1 of Set 2 | kruisfontein
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | kalmunai
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | raudeberg
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | kamina
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | te anau
# Processing Record 11 of Set 2 | galle
# Processing Record 12 of Set 2 | narsaq
# Processing Record 13 of Set 2 | westport
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | souillac
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | vostok
# Processing Record 20 of Set 2 | moba
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | mayo
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | araouane
# Processing Record 26 of Set 2 | saint george
# Processing Record 27 of Set 2 | ostrovnoy
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | mount darwin
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | texiguat
# Processing Record 34 of Set 2 | muroto
# Processing Record 35 of Set 2 | naze
# Processing Record 36 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | boyuibe
# Processing Record 39 of Set 2 | tirat karmel
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | isabela
# Processing Record 42 of Set 2 | mondolfo
# Processing Record 43 of Set 2 | anshun
# Processing Record 44 of Set 2 | narimanov
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | kewanee
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | verkh-usugli
# Processing Record 49 of Set 2 | taitung
# Processing Record 0 of Set 3 | nikolskoye
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | kavieng
# Processing Record 3 of Set 3 | marawi
# Processing Record 4 of Set 3 | pringsewu
# Processing Record 5 of Set 3 | abdanan
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | bayangol
# Processing Record 8 of Set 3 | huarmey
# Processing Record 9 of Set 3 | bambanglipuro
# Processing Record 10 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 3 | comodoro rivadavia
# Processing Record 12 of Set 3 | harsany
# Processing Record 13 of Set 3 | weimar
# Processing Record 14 of Set 3 | alice springs
# Processing Record 29 of Set 4 | severo-yeniseyskiy
# Processing Record 30 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 4 | esperance
# Processing Record 32 of Set 4 | berlevag
# Processing Record 33 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 34 of Set 4 | raha
# Processing Record 35 of Set 4 | teguise
# Processing Record 36 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | college
# Processing Record 39 of Set 4 | hervey bay
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | keuruu
# Processing Record 42 of Set 4 | barrow
# Processing Record 43 of Set 4 | sumisip
# Processing Record 44 of Set 4 | namatanai
# Processing Record 45 of Set 4 | meadow lake
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | antofagasta
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 0 of Set 5 | trinidad
# Processing Record 1 of Set 5 | chauk
# Processing Record 2 of Set 5 | khani
# Processing Record 3 of Set 5 | del rio
# Processing Record 4 of Set 5 | chara
# Processing Record 5 of Set 5 | muros
# Processing Record 6 of Set 5 | arlit
# Processing Record 7 of Set 5 | lodja
# Processing Record 8 of Set 5 | syracuse
# Processing Record 9 of Set 5 | carutapera
# Processing Record 10 of Set 5 | clyde river
# Processing Record 11 of Set 5 | tokonou
# Processing Record 12 of Set 5 | mazatlan
# Processing Record 13 of Set 5 | sayyan
# Processing Record 14 of Set 5 | palora
# Processing Record 15 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | kristiinankaupunki
# Processing Record 17 of Set 5 | coquimbo
# Processing Record 18 of Set 5 | aleksandrovskiy zavod
# Processing Record 19 of Set 5 | port shepstone
# Processing Record 20 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 5 | walvis bay
# Processing Record 22 of Set 5 | byron bay
# Processing Record 23 of Set 5 | henties bay
# Processing Record 24 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | thunder bay
# Processing Record 27 of Set 5 | pevek
# Processing Record 28 of Set 5 | kouroussa
# Processing Record 29 of Set 5 | san policarpo
# Processing Record 30 of Set 5 | salalah
# Processing Record 31 of Set 5 | ayan
# Processing Record 32 of Set 5 | kushmurun
# Processing Record 33 of Set 5 | boueni
# Processing Record 34 of Set 5 | tarko-sale
# Processing Record 35 of Set 5 | magdagachi
# Processing Record 36 of Set 5 | beringovskiy
# Processing Record 37 of Set 5 | bhatkal
# Processing Record 38 of Set 5 | kamir
# Processing Record 39 of Set 5 | dire dawa
# Processing Record 40 of Set 5 | bitam
# Processing Record 41 of Set 5 | houma
# Processing Record 42 of Set 5 | melilla
# Processing Record 43 of Set 5 | duz
# City not found. Skipping...
# Processing Record 44 of Set 5 | nizhneangarsk
# Processing Record 45 of Set 5 | faya
# Processing Record 46 of Set 5 | zhenlai
# Processing Record 47 of Set 5 | peno
# Processing Record 48 of Set 5 | tilichiki
# Processing Record 49 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 0 of Set 6 | goure
# Processing Record 1 of Set 6 | turan
# Processing Record 2 of Set 6 | wagar
# Processing Record 3 of Set 6 | belmonte
# Processing Record 4 of Set 6 | chuy
# Processing Record 5 of Set 6 | boende
# Processing Record 6 of Set 6 | norman wells
# Processing Record 7 of Set 6 | zhengjiatun
# Processing Record 8 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 6 | la palma
# Processing Record 10 of Set 6 | russell
# Processing Record 11 of Set 6 | usinsk
# Processing Record 12 of Set 6 | aromashevo
# Processing Record 13 of Set 6 | kirishi
# Processing Record 14 of Set 6 | sola
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | grand gaube
# Processing Record 17 of Set 6 | tasiilaq
# Processing Record 18 of Set 6 | vanimo
# Processing Record 19 of Set 6 | sisimiut
# Processing Record 20 of Set 6 | mitsamiouli
# Processing Record 21 of Set 6 | xinqing
# Processing Record 22 of Set 6 | neuquen
# Processing Record 23 of Set 6 | poum
# Processing Record 24 of Set 6 | aykhal
# Processing Record 25 of Set 6 | grenville
# Processing Record 26 of Set 6 | hay river
# Processing Record 27 of Set 6 | esmeraldas
# Processing Record 28 of Set 6 | saravan
# Processing Record 29 of Set 6 | ialibu
# Processing Record 30 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 6 | tripoli
# Processing Record 32 of Set 6 | khor
# Processing Record 33 of Set 6 | kharagpur
# Processing Record 34 of Set 6 | paso de carrasco
# Processing Record 35 of Set 6 | quelimane
# Processing Record 36 of Set 6 | lichinga
# Processing Record 37 of Set 6 | puerto madero
# Processing Record 38 of Set 6 | bowen
# Processing Record 39 of Set 6 | sehithwa
# Processing Record 40 of Set 6 | bocaranga
# City not found. Skipping...
# Processing Record 41 of Set 6 | yegros
# Processing Record 42 of Set 6 | freeport
# Processing Record 43 of Set 6 | merauke
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | nizwa
# Processing Record 46 of Set 6 | sept-iles
# Processing Record 47 of Set 6 | khuzhir
# Processing Record 48 of Set 6 | nanakuli
# Processing Record 49 of Set 6 | castro
# Processing Record 0 of Set 7 | jiblah
# Processing Record 1 of Set 7 | svobodnyy
# Processing Record 2 of Set 7 | alofi
# Processing Record 3 of Set 7 | zaliztsi
# Processing Record 4 of Set 7 | anadyr
# Processing Record 5 of Set 7 | half moon bay
# Processing Record 6 of Set 7 | oranjestad
# Processing Record 7 of Set 7 | yar-sale
# Processing Record 8 of Set 7 | iqaluit
# Processing Record 9 of Set 7 | verkhnyaya inta
# Processing Record 10 of Set 7 | bambous virieux
# Processing Record 11 of Set 7 | puerto del rosario
# Processing Record 12 of Set 7 | angoram
# Processing Record 13 of Set 7 | skhisma
# Processing Record 3 of Set 10 | montemor-o-novo
# Processing Record 4 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 10 | calvinia
# Processing Record 7 of Set 10 | turayf
# Processing Record 8 of Set 10 | vestmanna
# Processing Record 9 of Set 10 | kieta
# Processing Record 10 of Set 10 | maragogi
# Processing Record 11 of Set 10 | ponta delgada
# Processing Record 12 of Set 10 | salinopolis
# Processing Record 13 of Set 10 | ylivieska
# Processing Record 14 of Set 10 | emerald
# Processing Record 15 of Set 10 | dakar
# Processing Record 16 of Set 10 | korla
# Processing Record 17 of Set 10 | katsuura
# Processing Record 18 of Set 10 | deputatskiy
# Processing Record 19 of Set 10 | taltal
# Processing Record 20 of Set 10 | khewra
# Processing Record 21 of Set 10 | baruun-urt
# Processing Record 22 of Set 10 | peniche
# Processing Record 23 of Set 10 | cayenne
# Processing Record 24 of Set 10 | roma
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | kolokani
# Processing Record 27 of Set 10 | umm jarr
# City not found. Skipping...
# Processing Record 28 of Set 10 | bathsheba
# Processing Record 29 of Set 10 | tomatlan
# Processing Record 30 of Set 10 | turukhansk
# Processing Record 31 of Set 10 | stornoway
# Processing Record 32 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 10 | marzuq
# Processing Record 34 of Set 10 | semey
# Processing Record 35 of Set 10 | saint-pierre
# Processing Record 36 of Set 10 | olafsvik
# Processing Record 37 of Set 10 | bongandanga
# Processing Record 38 of Set 10 | chom bung
# City not found. Skipping...
# Processing Record 39 of Set 10 | alta floresta
# Processing Record 40 of Set 10 | kindu
# Processing Record 41 of Set 10 | sahuaripa
# Processing Record 42 of Set 10 | griffith
# Processing Record 43 of Set 10 | galveston
# Processing Record 44 of Set 10 | rehoboth
# Processing Record 45 of Set 10 | mazamari
# Processing Record 46 of Set 10 | le vauclin
# Processing Record 47 of Set 10 | lewiston
# Processing Record 48 of Set 10 | uniao da victoria
# City not found. Skipping...
# Processing Record 49 of Set 10 | nusaybin
# Processing Record 0 of Set 11 | mackay
# Processing Record 1 of Set 11 | myre
# Processing Record 2 of Set 11 | gigmoto
# Processing Record 3 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 4 of Set 11 | morondava
# Processing Record 5 of Set 11 | hami
# Processing Record 6 of Set 11 | antalaha
# Processing Record 7 of Set 11 | mount pleasant
# Processing Record 8 of Set 11 | kabinda
# Processing Record 9 of Set 11 | novobirilyussy
# Processing Record 10 of Set 11 | mao
# Processing Record 11 of Set 11 | twentynine palms
# Processing Record 12 of Set 11 | kapiri mposhi
# Processing Record 13 of Set 11 | tiznit
# Processing Record 14 of Set 11 | brigantine
# Processing Record 15 of Set 11 | constitucion
# Processing Record 16 of Set 11 | belyy yar
# Processing Record 17 of Set 11 | nedjo
# Processing Record 18 of Set 11 | piacabucu
# Processing Record 19 of Set 11 | itoigawa
# Processing Record 20 of Set 11 | vacaria
# Processing Record 21 of Set 11 | sechura
# Processing Record 22 of Set 11 | dingle
# Processing Record 23 of Set 11 | unai
# Processing Record 24 of Set 11 | amarante do maranhao
# Processing Record 25 of Set 11 | buala
# Processing Record 26 of Set 11 | boa vista
# Processing Record 27 of Set 11 | krasnovishersk
# Processing Record 28 of Set 11 | marsh harbour
# Processing Record 29 of Set 11 | praya
# Processing Record 30 of Set 11 | hamilton
# Processing Record 31 of Set 11 | bandar maharani
# City not found. Skipping...
# Processing Record 32 of Set 11 | moose factory
# Processing Record 33 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 11 | tornio
# Processing Record 35 of Set 11 | pineville
# Processing Record 36 of Set 11 | peleduy
# Processing Record 37 of Set 11 | lata
# Processing Record 38 of Set 11 | davila
# Processing Record 39 of Set 11 | kanniyakumari
# Processing Record 40 of Set 11 | sabaudia
# Processing Record 41 of Set 11 | varberg
# Processing Record 42 of Set 11 | dire
# Processing Record 43 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 11 | namibe
# Processing Record 45 of Set 11 | zhangye
# Processing Record 46 of Set 11 | sirur
# Processing Record 47 of Set 11 | clearwater
# Processing Record 48 of Set 11 | nemuro
# Processing Record 49 of Set 11 | road town
# Processing Record 0 of Set 12 | tevaitoa
# Processing Record 1 of Set 12 | yulara
# Processing Record 2 of Set 12 | mangrol
# Processing Record 3 of Set 12 | denizli
# Processing Record 4 of Set 12 | tabou
# Processing Record 5 of Set 12 | mendeleyevo
# Processing Record 6 of Set 12 | zhigansk
# Processing Record 7 of Set 12 | okhotsk
# Processing Record 8 of Set 12 | gizo
# Processing Record 9 of Set 12 | ocampo
# Processing Record 10 of Set 12 | sakakah
# Processing Record 11 of Set 12 | andarab
# City not found. Skipping...
# Processing Record 12 of Set 12 | taoudenni
# Processing Record 13 of Set 12 | rantauprapat
# Processing Record 14 of Set 12 | namie
# Processing Record 15 of Set 12 | aberfeldy
# Processing Record 16 of Set 12 | quixada
# Processing Record 17 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 12 | khash
# Processing Record 19 of Set 12 | nome
# Processing Record 20 of Set 12 | garoua
# Processing Record 21 of Set 12 | ceres
# Processing Record 22 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 12 | umm kaddadah
# Processing Record 24 of Set 12 | awjilah
# Processing Record 25 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 26 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 12 | broome
# Processing Record 28 of Set 12 | san ramon
# Processing Record 29 of Set 12 | gillette
# Processing Record 30 of Set 12 | tevriz
# Processing Record 31 of Set 12 | saint anthony
# Processing Record 32 of Set 12 | mumford
# Processing Record 33 of Set 12 | broager
# Processing Record 34 of Set 12 | lincoln
# Processing Record 35 of Set 12 | noumea
# Processing Record 36 of Set 12 | aitape
# Processing Record 37 of Set 12 | umea
# Processing Record 38 of Set 12 | mirnyy
# Processing Record 39 of Set 12 | honningsvag
# Processing Record 40 of Set 12 | scarborough
# Processing Record 41 of Set 12 | quang ngai
# Processing Record 42 of Set 12 | araguacu
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
# convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# city          537
# Lat           537
# Lng           537
# Max Temp      537
# Humidity      537
# Cloudiness    537
# Wind Speed    537
# Country       537
# Date          537
# dtype: int64

# %%
# display the sample data
city_data_df.head()
# Out:
#               city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             hilo  19.7297 -155.0900     77.11        85          75
# 1      east london -33.0153   27.9116     74.73        84          23
# 2   cabo san lucas  22.8909 -109.9124     81.61        50           0
# 3      yellowknife  62.4560 -114.3525      1.69        95         100
# 4  arraial do cabo -22.9661  -42.0278     78.66        83          75
#
#    Wind Speed Country        Date
# 0        5.75      US  1675725314
# 1       15.28      ZA  1675725318
# 2       13.80      MX  1675725200
# 3        7.49      CA  1675725053
# 4        5.75      BR  1675725322

# %%
# export the city_data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="city_id")

# %%
# read the saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="city_id")

# display sample data
city_data_df.head()
# Out:
#                     city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# city_id
# 0                   hilo  19.7297 -155.0900     77.11        85          75
# 1            east london -33.0153   27.9116     74.73        84          23
# 2         cabo san lucas  22.8909 -109.9124     81.61        50           0
# 3            yellowknife  62.4560 -114.3525      1.69        95         100
# 4        arraial do cabo -22.9661  -42.0278     78.66        83          75
#
#          Wind Speed Country        Date
# city_id
# 0              5.75      US  1675725314
# 1             15.28      ZA  1675725318
# 2             13.80      MX  1675725200
# 3              7.49      CA  1675725053
# 4              5.75      BR  1675725322

# %%
# build scatter plot for latitude vs. temperature 
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker="o", facecolors="darksalmon", edgecolors="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature")
plt.grid()

# save the figure 
plt.savefig("output_data/Fig1.png")

plt.show()

# %%
# build scatter plot for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker="o", facecolors="darksalmon", edgecolors="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity")
plt.grid()

# save the figure 
plt.savefig("output_data/Fig2.png")

plt.show()

# %%
# build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker="o", facecolors="darksalmon", edgecolors="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")
plt.grid()

# save the figure 
plt.savefig("output_data/Fig3.png")

plt.show()

# %%
# build scatter plot for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker="o", facecolors="darksalmon", edgecolors="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed")
plt.grid()

# save the figure 
plt.savefig("output_data/Fig4.png")

plt.show()

# %%
# compute linear regression for each relationship

# %%
# create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]
northern_hemi_df.head()
# Out:
#                    city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# city_id
# 0                  hilo  19.7297 -155.0900     77.11        85          75
# 2        cabo san lucas  22.8909 -109.9124     81.61        50           0
# 3           yellowknife  62.4560 -114.3525      1.69        95         100
# 8              victoria  22.2855  114.1577     68.95        89          92
# 9              khatanga  71.9667  102.5000    -41.48       100          56
#
#          Wind Speed Country        Date
# city_id
# 0              5.75      US  1675725314
# 2             13.80      MX  1675725200
# 3              7.49      CA  1675725053
# 8              3.00      HK  1675725249
# 9              3.09      RU  1675725325

# %%
# create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]
southern_hemi_df.head()
# Out:
#                              city      Lat       Lng  Max Temp  Humidity  \
# city_id
# 1                     east london -33.0153   27.9116     74.73        84
# 4                 arraial do cabo -22.9661  -42.0278     78.66        83
# 5        sao jose da coroa grande  -8.8978  -35.1478     77.95        76
# 6                         mataura -46.1927  168.8643     63.30        64
# 7                        lorengau  -2.0226  147.2712     77.09        94
#
#          Cloudiness  Wind Speed Country        Date
# city_id
# 1                23       15.28      ZA  1675725318
# 4                75        5.75      BR  1675725322
# 5                99        8.70      BR  1675725323
# 6                70        8.81      NZ  1675725324
# 7               100       10.83      PG  1675725324

# %%
# temperature vs latitude linear regression plot

# %%
# linear regression on Northern Hemisphere 
temp_nh_x_values = northern_hemi_df['Lat'].astype("float")
temp_nh_y_values = northern_hemi_df['Max Temp'].astype("float")

# run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(temp_nh_x_values, temp_nh_y_values)
regress_values = temp_nh_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter plot
plt.scatter(temp_nh_x_values, temp_nh_y_values)

# plot regression line 
plt.plot(temp_nh_x_values, regress_values, "r-")
plt.annotate(line_eq, (6,-10), fontsize=15, color="red")

# label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

# print r squared value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.7315293121564991

# %%
# linear regression on Southern Hemisphere 
temp_sh_x_values = southern_hemi_df['Lat'].astype("float")
temp_sh_y_values = southern_hemi_df['Max Temp'].astype("float")

# run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(temp_sh_x_values, temp_sh_y_values)
regress_values = temp_sh_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter plot
plt.scatter(temp_sh_x_values, temp_sh_y_values)

# plot regression line 
plt.plot(temp_sh_x_values, regress_values, "r-")
plt.annotate(line_eq, (-50,50), fontsize=15, color="red")

# label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

# print r squared value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.20543737975941107

# %%
# analysis

# Latitude (Northern Hemisphere) vs temperature had a r value of 0.7315 which is a strong negative correlation.
# This mean that as latitude increases, temperature decreases. 
# This plot shows that it gets cooler as you travel further from the equator.

# Latitude (Southern Hemisphere) vs temperature had a r value of 0.205 which is a very weak positive correlation.
# This means that as latitude increases, temperature slightly increases 
# meaning it gets slightly warmer as you get closer to the equator.

# %%
# humidity vs latitude linear regression plot

# %%
# linear regression on northern hemisphere 
hum_nh_x_values = northern_hemi_df['Lat'].astype("float")
hum_nh_y_values = northern_hemi_df['Humidity'].astype("float")

# run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(hum_nh_x_values, hum_nh_y_values)
regress_values = hum_nh_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter plot
plt.scatter(hum_nh_x_values, hum_nh_y_values)

# plot regression line 
plt.plot(hum_nh_x_values, regress_values, "r-")
plt.annotate(line_eq, (45,25), fontsize=15, color="red")

# label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# print r squared value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.18408726591066435

# %%
# linear regression on sorthern hemisphere 
hum_sh_x_values = southern_hemi_df['Lat'].astype("float")
hum_sh_y_values = southern_hemi_df['Humidity'].astype("float")

# run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(hum_sh_x_values, hum_sh_y_values)
regress_values = hum_sh_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter plot
plt.scatter(hum_sh_x_values, hum_sh_y_values)

# plot regression line 
plt.plot(hum_sh_x_values, regress_values, "r-")
plt.annotate(line_eq,(-25,30), fontsize=15, color="red")

# label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# print r squared value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.11708853176870349

# %%
# analysis 

# Latitude (Northern Hemisphere) vs humidity had a correlation coefficient of 0.184, 
# which means either no correaltion of a very weak correlation. 
# The line of regression shows that as latitude increases, humidity increases 
# meaning it gets more humid as you travel further from the equator.

# Latitude (Southern Hemisphere) vs humidity had an r value of 0.117, 
# meaning there is either no correlation or a very weak correlation.
# Line of regression shows that as latitude increases, humidity increases, 
# which would mean that as you get closer to the equator, humidity.

# Since these two plots contradict eachother, there is no correlation between latitude and humidity.

# %%
# cloudiness vs latitude linear regression plot

# %%
# linear regression on northern hemisphere 
cloud_nh_x_values = northern_hemi_df['Lat'].astype("float")
cloud_nh_y_values = northern_hemi_df['Cloudiness'].astype("float")

# run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(cloud_nh_x_values, cloud_nh_y_values)
regress_values = cloud_nh_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter plot
plt.scatter(cloud_nh_x_values, cloud_nh_y_values)

# plot regression line 
plt.plot(cloud_nh_x_values, regress_values, "r-")
plt.annotate(line_eq, (45,25), fontsize=15, color="red")

# label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# print r squared value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.07258929934336833

# %%
# linear regression on southern hemisphere 
cloud_sh_x_values = southern_hemi_df['Lat'].astype("float")
cloud_sh_y_values = southern_hemi_df['Cloudiness'].astype("float")

# run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(cloud_sh_x_values, cloud_sh_y_values)
regress_values = cloud_sh_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter plot
plt.scatter(cloud_sh_x_values, cloud_sh_y_values)

# plot regression line 
plt.plot(cloud_sh_x_values, regress_values, "r-")
plt.annotate(line_eq, (-50,65), fontsize=15, color="red")

# label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# print r squared value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.14968594751314115

# %%
# analysis 

# The r value determining the correlation between Latitude (Northern Hemisphere) and cloudiness is 0.0726. 
# The r value is 0.1497 when looking at Latitude (Southern Hemisphere) and cloudiness. 
# This mean there is no correlation between latitude and cloudiness.

# %%
# wind speed vs latitude linear regression plot

# %%
# linear regression on northern hemisphere 
wind_nh_x_values = northern_hemi_df['Lat'].astype("float")
wind_nh_y_values = northern_hemi_df['Wind Speed'].astype("float")

# run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(wind_nh_x_values, wind_nh_y_values)
regress_values = wind_nh_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter plot
plt.scatter(wind_nh_x_values, wind_nh_y_values)

# plot regression line 
plt.plot(wind_nh_x_values, regress_values, "r-")
plt.annotate(line_eq, (5,30), fontsize=15, color="red")

# label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# print r squared value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.0007734532156689493

# %%
# linear regression on southern hemisphere 
wind_sh_x_values = southern_hemi_df['Lat'].astype("float")
wind_sh_y_values = southern_hemi_df['Wind Speed'].astype("float")

# run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(wind_sh_x_values, wind_sh_y_values)
regress_values = wind_sh_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter plot
plt.scatter(wind_sh_x_values, wind_sh_y_values)

# plot regression line 
plt.plot(wind_sh_x_values, regress_values, "r-")
plt.annotate(line_eq, (-30,23), fontsize=15, color="red")

# label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# print r squared value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.05018911793342266

# %%
# analysis

# Latitude (Northern Hemisphere) vs wind speed had a correlation coefficient of 0.0008. 
# Latitude (Southern Hemisphere) vs wind speed had a r value of 0.0502. 
# These are both very small numbers, therefore there is no correlation between latitude and wind speed.
